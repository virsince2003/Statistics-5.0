# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
#     Estimation statistics is about making educated guesses (estimates) about population parameters using sample data. Point estimates provide a single value as the best guess, while interval estimates offer a range of values along with confidence levels for the true parameter.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
import numpy as np 
def func(s_mean,s_std_dev):
    return s_mean

# %% [markdown]
# s_mean=50
# s_std_dev=10
# func_pop=func(s_mean,s_std_dev)
# print("Estimated Population Mean:", s_mean)

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
#     Hypothesis testing is a statistical method used to assess claims about populations using sample data. It ensures data-driven decision-making, validates theories, and controls errors in various fields, making it crucial for evidence-based conclusions.

# %% [markdown]
# Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %% [markdown]
#     Null Hypothesis (H0):Average weight of male college students ≤ Average weight of female college students
#
#     Alternative Hypothesis H1: Average weight of male college students > Average weight of female college students

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %%
import numpy as np 
from scipy.stats import ttest_ind

# %%
def test_samples(sample1,sample2, alpha=0.05):
    t_value, p_value=ttest_ind(sample1,sample2)
    
    if p_value<alpha:
        print("Reject the null hypothesis!!. Means are different .")
    else:
        print("Fail to reject the null hypothesis!!. There is no evidence to prove it wrong")
    return p_value, t_value

# %%
sample_male = np.array([70, 75, 68, 72, 74, 71, 69, 73])
sample_female = np.array([65, 68, 72, 67, 70, 69, 66, 68])
t_stats_,p_value_=test_samples(sample_male,sample_female)
print("T-statistic:", t_stats_)
print("P-value:", p_value_)
# Out:
# Reject the null hypothesis!!. Means are different .
# T-statistic: 0.012098094529565208
# P-value: 2.880548728213039

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
#     Null hypothesis (H0): Assumes no significant difference or effect in the population.
#         Example: H0: The mean scores of two groups are equal.
#
#     Alternative hypothesis (H1): Claims a significant difference or effect in the population.
#         Example: H1: The mean score of one group is higher than the other.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
#     Formulate hypotheses (H0 and H1).
#     Set significance level (α).
#     Collect a representative sample.
#     Choose the appropriate statistical test.
#     Calculate the test statistic.
#     Determine the critical region based on α.
#     Calculate the p-value.
#     Make a decision: reject or fail to reject H0.
#     Draw conclusions based on the decision.

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
#     The p-value is the probability of observing the sample data or more extreme results under the assumption that the null hypothesis is true. It helps determine the strength of evidence against the null hypothesis. A small p-value (p ≤ α) leads to rejecting the null hypothesis, while a large p-value (p > α) means the null hypothesis cannot be rejected. The p-value plays a central role in making decisions in hypothesis testing.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
from scipy.stats import t 
import matplotlib.pyplot as plt
ddof=10 
x=np.linspace(-5,5,1000)
students_t_test=t.pdf(x,ddof)
plt.plot(students_t_test,'H',alpha=0.2,color="orange")
plt.xlabel("X")
plt.ylabel("Probability Density Function (PDF)")
plt.yticks(color="green")
plt.xticks(color="green")
plt.title("Student t-distribution")
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
sample1 = np.array([34.5, 35.2, 36.1, 33.9, 35.5])
sample2 = np.array([32.8, 34.2, 33.5, 32.9, 34.6])
alpha=0.05
t_stat, p_value = ttest_ind(sample1,sample2)
if p_value<alpha:
    print("Reject the null hypothesis!!. Means are different .")
else:
    print("Fail to reject the null hypothesis!!. There is no evidence to prove it wrong")
print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# Reject the null hypothesis!!. Means are different .
# T-statistic: 2.758033686629134
# P-value: 0.02474982770508916

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
#     Student's t-distribution is used in statistical inference for small sample sizes or when the population standard deviation is unknown. It is more robust than the standard normal distribution when dealing with limited data.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
#     The t-statistic measures the difference between the sample mean and the hypothesized population mean, considering the sample size and variability. Its formula for a one-sample t-test is:
#
# t = (sample_mean - population_mean) / (sample_standard_deviation / √sample_size)
#
#     It follows a t-distribution with degrees of freedom, essential for hypothesis testing and making decisions.

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of  $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %%
import scipy.stats as  stats
def t_values(n,sample_mean,confidence_intervel,sample_deviation):
    standered_error=sample_deviation/n**0.5
    degree_of_freedom=n-1
    value=stats.t.ppf((1+confidence_intervel)/2,degree_of_freedom)
    lower_value=sample_mean-value*standered_error
    upper_value=sample_mean+value*standered_error
    return lower_value.round(), upper_value.round()

# %%
t_values(50,500,0.95,50)
# Out:
# (486.0, 514.0)

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
def values(n,sample_mean, sample_deviation, hypothetical_population_mean,significance_level):
    standard_error=sample_deviation/n**0.5
    
    degree_of_freedom=n-1
    T_value=stats.t.pdf(1 - significance_level, degree_of_freedom)
    t_statistic=(sample_mean-hypothetical_population_mean)/standard_error
    if T_value>significance_level:
        print("Reject the null hypothesis: The drug decreases blood pressure by 10 mmHg.")
    else:
        print("Fail to reject the null hypothesis: There is no significant evidence that the drug decreases blood pressure by 10 mmHg.")

# %%
values(100,8,3,10,0.05)
# Out:
# Reject the null hypothesis: The drug decreases blood pressure by 10 mmHg.

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %%
def value_s(n,sample_mean, population_deviation, hypothetical_population_mean_,significance_level):
    standard_error_=population_deviation/n**0.5
    
    degre_of_freedom=n-1
    tt_value=stats.t.pdf(1 - significance_level, degre_of_freedom)
    t_statistic=(sample_mean-hypothetical_population_mean_)/standard_error_
    if tt_value>significance_level:
         print("Reject the null hypothesis: The true mean weight of the products is less than 5 pounds.")
    else:
        print("Fail to reject the null hypothesis: There is no significant evidence that the true mean weight of the products is less than 5 pounds.")

# %%
value_s(25,4.8,0.5,5,0.05)
# Out:
# Reject the null hypothesis: The true mean weight of the products is less than 5 pounds.

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1=30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %%
from scipy import stats
def test_samples(mean1,n1,std_dev1,mean2,n2,std_dev2,alpha=0.01):
    ddof=n1+n2-2
   # t=(mean1-mean2)/(((std_dev1)**2/n1)+((std_dev2)**2/n2)**0.5
    t_statistic, p_value = stats.ttest_ind_from_stats(mean1, std_dev1, n1, mean2, std_dev2, n2)
    critical_t_= stats.t.ppf(1 - alpha / 2, ddof)
    if t_statistic > critical_t_:
        print("Reject the null hypothesis. There is a significant difference between the population means of the two groups.")
    else:
        print("Fail to reject the null hypothesis. There is not enough evidence to conclude that the population means are different.")
    return t_statistic, p_value,critical_t_

# %%
test_samples(80,30,10,75,40,8)
# Out:
# Fail to reject the null hypothesis. There is not enough evidence to conclude that the population means are different.
# (2.323967729699292, 0.02312301341372599, 2.6500812928169553)

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
def value_ss(n1,sample_mean1, sample_std_deviation,confidence_level):
    standard_error_= sample_std_deviation/n1**0.5
    degre_of_freedom=n1-1
    tt_value=stats.t.ppf(confidence_level, degre_of_freedom)
    lower_value=sample_mean1-tt_value*standard_error_
    upper_value=sample_mean1+tt_value*standard_error_
    print(f"Population Mean Estimate: {sample_mean1:.2f}")
    print(f"99% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# %%
value_ss(50,4,1.5,0.99)
# Out:
# Population Mean Estimate: 4.00
# 99% Confidence Interval: (3.43, 4.57)
